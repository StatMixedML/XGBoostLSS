# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/StatMixedML/XGBoostLSS/blob/master/examples/ZIP_example.ipynb)

# %% [markdown]
# # Imports

# %%
from xgboostlss.model import *
from xgboostlss.distributions.ZIP import *

from sklearn.model_selection import train_test_split
import pandas as pd
import multiprocessing
import plotnine
from plotnine import *
plotnine.options.figure_size = (18, 9)
n_cpu = multiprocessing.cpu_count()

# %% [markdown]
# # Data

# %%
# For more information on the dataset see: https://stats.oarc.ucla.edu/stata/dae/zero-inflated-poisson-regression/
data = pd.read_stata("http://www.stata-press.com/data/r10/fish.dta")
y = data["count"].values.reshape(-1,1)
X = data.drop(columns="count")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

dtrain = xgb.DMatrix(X_train, label=y_train, nthread=n_cpu)
dtest = xgb.DMatrix(X_test, nthread=n_cpu)

# %% [markdown]
# # Distribution Selection

# %%
# Specifies Zero-Inflated Poisson distribution. See ?ZIP for an overview.
xgblss = XGBoostLSS(
    ZIP(stabilization="None",      # Options are "None", "MAD", "L2".
        response_fn="softplus",    # Function to transform the scale-parameter, e.g., "exp" or "softplus".
        loss_fn="nll"              # Loss function. Options are "nll" (negative log-likelihood) or "crps"(continuous ranked probability score).
       )    
)

# %% [markdown]
# # Hyper-Parameter Optimization

# %%
# Any XGBoost hyperparameter can be tuned, where the structure of the parameter dictionary needs to be as follows:

    # Float/Int sample_type
        # {"param_name": ["sample_type", low, high, log]}
            # sample_type: str, Type of sampling, e.g., "float" or "int"
            # low: int, Lower endpoint of the range of suggested values
            # high: int, Upper endpoint of the range of suggested values
            # log: bool, Flag to sample the value from the log domain or not
        # Example: {"eta": "float", low=1e-5, high=1, log=True]}

    # Categorical sample_type
        # {"param_name": ["sample_type", ["choice1", "choice2", "choice3", "..."]]}
            # sample_type: str, Type of sampling, either "categorical"
            # choice1, choice2, choice3, ...: str, Possible choices for the parameter
        # Example: {"booster": ["categorical", ["gbtree", "dart"]]}

    # For parameters without tunable choice (this is needed if tree_method = "gpu_hist" and gpu_id needs to be specified)
        # {"param_name": ["none", [value]]},
            # param_name: str, Name of the parameter
            # value: int, Value of the parameter
        # Example: {"gpu_id": ["none", [0]]}

# Depending on which parameters are optimized, it might happen that some of them are not used, e.g., when {"booster":  ["categorical", ["gbtree", "gblinear"]]} and {"max_depth": ["int", 1, 10, False]} are
# specified, max_depth is not used when gblinear is sampled, since it has no such argument.

param_dict = {
    "eta":              ["float", {"low": 1e-5,   "high": 1,     "log": True}],
    "max_depth":        ["int",   {"low": 1,      "high": 10,    "log": False}],
    "gamma":            ["float", {"low": 1e-8,   "high": 40,    "log": True}],
    "subsample":        ["float", {"low": 0.2,    "high": 1.0,   "log": False}],
    "colsample_bytree": ["float", {"low": 0.2,    "high": 1.0,   "log": False}],
    "booster":          ["categorical", ["gbtree"]],
    # "tree_method":    ["categorical", ["auto", "approx", "hist", "gpu_hist"]],
    # "gpu_id":         ["none", [0]]
}

np.random.seed(123)
opt_param = xgblss.hyper_opt(param_dict,
                             dtrain,
                             num_boost_round=100,        # Number of boosting iterations.
                             nfold=5,                    # Number of cv-folds.
                             early_stopping_rounds=20,   # Number of early-stopping rounds
                             max_minutes=5,              # Time budget in minutes, i.e., stop study after the given number of minutes.
                             n_trials=None,              # The number of trials. If this argument is set to None, there is no limitation on the number of trials.
                             silence=False,              # Controls the verbosity of the trail, i.e., user can silence the outputs of the trail.
                             seed=123,                   # Seed used to generate cv-folds.
                             hp_seed=None                # Seed for random number generator used in the Bayesian hyperparameter search.
                            )
# Out:
# [I 2023-06-07 10:49:01,405] A new study created in memory with name: XGBoostLSS Hyper-Parameter Optimization
# C:\Users\maerzale\.virtualenvs\XGBoostLSS-vIPRRz-M\lib\site-packages\optuna\progress_bar.py:56: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#    0%|          | 00:00/05:00
# [I 2023-06-07 10:49:07,760] Trial 0 finished with value: 174.28059380000002 and parameters: {'eta': 0.0014979451469003442, 'max_depth': 10, 'gamma': 15.677943906387426, 'subsample': 0.9076938530186172, 'colsample_bytree': 0.7027432751576757, 'booster': 'gbtree'}. Best is trial 0 with value: 174.28059380000002.
# [I 2023-06-07 10:49:13,307] Trial 1 finished with value: 86.7250734 and parameters: {'eta': 0.2709211148388839, 'max_depth': 2, 'gamma': 0.00238542696705079, 'subsample': 0.462478988774979, 'colsample_bytree': 0.4165952008847251, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:16,640] Trial 2 finished with value: 186.67963519999998 and parameters: {'eta': 0.00024633593941598107, 'max_depth': 9, 'gamma': 5.6398674038552615e-08, 'subsample': 0.20038264177595722, 'colsample_bytree': 0.2825672856486999, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:21,865] Trial 3 finished with value: 174.82254319999998 and parameters: {'eta': 0.0033383501539750236, 'max_depth': 9, 'gamma': 0.007106843315563061, 'subsample': 0.27853978574549426, 'colsample_bytree': 0.8306708027167959, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:27,503] Trial 4 finished with value: 185.7113372 and parameters: {'eta': 0.00018517818809472036, 'max_depth': 9, 'gamma': 5.6119395635032125, 'subsample': 0.893488224964744, 'colsample_bytree': 0.32397421265275517, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:33,018] Trial 5 finished with value: 180.9758378 and parameters: {'eta': 0.0005827384234184066, 'max_depth': 8, 'gamma': 9.83829970117975, 'subsample': 0.5229667777102316, 'colsample_bytree': 0.9634532292065792, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:38,983] Trial 6 finished with value: 184.047908 and parameters: {'eta': 0.0011415058485284126, 'max_depth': 3, 'gamma': 9.55832397360099e-07, 'subsample': 0.8897868848987764, 'colsample_bytree': 0.2734115716297737, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:44,279] Trial 7 finished with value: 186.62577979999998 and parameters: {'eta': 2.346951342312089e-05, 'max_depth': 4, 'gamma': 1.0512441526292576e-07, 'subsample': 0.30984522185185215, 'colsample_bytree': 0.44457433255962925, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:49,786] Trial 8 finished with value: 182.43839880000002 and parameters: {'eta': 0.0019853988735537044, 'max_depth': 2, 'gamma': 0.36190674291137875, 'subsample': 0.34043348208205404, 'colsample_bytree': 0.40649761314647015, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:55,336] Trial 9 finished with value: 186.3712722 and parameters: {'eta': 3.81984961569825e-05, 'max_depth': 2, 'gamma': 12.636038785988388, 'subsample': 0.7293641218753062, 'colsample_bytree': 0.69698281324891, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:49:59,062] Trial 10 finished with value: 90.2931854 and parameters: {'eta': 0.8144944244365455, 'max_depth': 6, 'gamma': 8.099853491200767e-05, 'subsample': 0.48753078416538365, 'colsample_bytree': 0.5211650196811252, 'booster': 'gbtree'}. Best is trial 1 with value: 86.7250734.
# [I 2023-06-07 10:50:02,296] Trial 11 finished with value: 85.22000560000001 and parameters: {'eta': 0.7822827440959992, 'max_depth': 6, 'gamma': 7.941940567282685e-05, 'subsample': 0.502263954242423, 'colsample_bytree': 0.5245052009093318, 'booster': 'gbtree'}. Best is trial 11 with value: 85.22000560000001.
# [I 2023-06-07 10:50:05,696] Trial 12 finished with value: 87.0454796 and parameters: {'eta': 0.9284546420351405, 'max_depth': 6, 'gamma': 0.00039790406252593027, 'subsample': 0.6339933505958949, 'colsample_bytree': 0.5534066993284068, 'booster': 'gbtree'}. Best is trial 11 with value: 85.22000560000001.
# [I 2023-06-07 10:50:11,926] Trial 13 finished with value: 98.16357359999999 and parameters: {'eta': 0.09248274667657004, 'max_depth': 5, 'gamma': 1.2602429365612636e-05, 'subsample': 0.44495591622174946, 'colsample_bytree': 0.42757550283181117, 'booster': 'gbtree'}. Best is trial 11 with value: 85.22000560000001.
# [I 2023-06-07 10:50:17,571] Trial 14 finished with value: 84.0051752 and parameters: {'eta': 0.09187606743607275, 'max_depth': 1, 'gamma': 0.005417953828100726, 'subsample': 0.6238596128669895, 'colsample_bytree': 0.6105195833247967, 'booster': 'gbtree'}. Best is trial 14 with value: 84.0051752.
# [I 2023-06-07 10:50:23,047] Trial 15 finished with value: 84.7453088 and parameters: {'eta': 0.05905930457389612, 'max_depth': 7, 'gamma': 0.0354147152001238, 'subsample': 0.6500010861314234, 'colsample_bytree': 0.632345438751189, 'booster': 'gbtree'}. Best is trial 14 with value: 84.0051752.
# [I 2023-06-07 10:50:28,337] Trial 16 finished with value: 115.7828606 and parameters: {'eta': 0.022978058321506657, 'max_depth': 1, 'gamma': 0.07681504435760592, 'subsample': 0.7205377322871565, 'colsample_bytree': 0.6735571971100323, 'booster': 'gbtree'}. Best is trial 14 with value: 84.0051752.
# [I 2023-06-07 10:50:33,930] Trial 17 finished with value: 113.1179136 and parameters: {'eta': 0.019074659862141175, 'max_depth': 7, 'gamma': 0.020677030243656143, 'subsample': 0.6277121897715239, 'colsample_bytree': 0.6215904458537715, 'booster': 'gbtree'}. Best is trial 14 with value: 84.0051752.
# [I 2023-06-07 10:50:40,164] Trial 18 finished with value: 74.4447296 and parameters: {'eta': 0.07548010052523574, 'max_depth': 4, 'gamma': 0.24149008550974432, 'subsample': 0.766170931259512, 'colsample_bytree': 0.7818613283559205, 'booster': 'gbtree'}. Best is trial 18 with value: 74.4447296.
# [I 2023-06-07 10:50:41,362] Trial 19 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:50:47,215] Trial 20 finished with value: 75.94077739999999 and parameters: {'eta': 0.11197102189467556, 'max_depth': 1, 'gamma': 0.0039982052578040675, 'subsample': 0.8178666511137825, 'colsample_bytree': 0.8121319850551122, 'booster': 'gbtree'}. Best is trial 18 with value: 74.4447296.
# [I 2023-06-07 10:50:52,748] Trial 21 finished with value: 73.10703500000001 and parameters: {'eta': 0.14423804199200546, 'max_depth': 1, 'gamma': 0.0015369348962984103, 'subsample': 0.9944795480991019, 'colsample_bytree': 0.8373022752590871, 'booster': 'gbtree'}. Best is trial 21 with value: 73.10703500000001.
# [I 2023-06-07 10:50:56,898] Trial 22 finished with value: 67.7816536 and parameters: {'eta': 0.20398265766085252, 'max_depth': 3, 'gamma': 0.0013092189639554634, 'subsample': 0.9931603623143818, 'colsample_bytree': 0.8849568841257421, 'booster': 'gbtree'}. Best is trial 22 with value: 67.7816536.
# [I 2023-06-07 10:51:00,491] Trial 23 finished with value: 68.21683139999999 and parameters: {'eta': 0.27954664921101774, 'max_depth': 3, 'gamma': 0.00048625977086976777, 'subsample': 0.9865073547154112, 'colsample_bytree': 0.8827268838206658, 'booster': 'gbtree'}. Best is trial 22 with value: 67.7816536.
# [I 2023-06-07 10:51:03,699] Trial 24 finished with value: 67.7187814 and parameters: {'eta': 0.31879206748983624, 'max_depth': 3, 'gamma': 0.0004018522314647509, 'subsample': 0.9917644312309495, 'colsample_bytree': 0.9500881590725242, 'booster': 'gbtree'}. Best is trial 24 with value: 67.7187814.
# [I 2023-06-07 10:51:07,028] Trial 25 finished with value: 67.4505798 and parameters: {'eta': 0.3343839995002027, 'max_depth': 3, 'gamma': 0.00011963809320129572, 'subsample': 0.9993114822441888, 'colsample_bytree': 0.9691051062451982, 'booster': 'gbtree'}. Best is trial 25 with value: 67.4505798.
# [I 2023-06-07 10:51:10,275] Trial 26 finished with value: 68.3695068 and parameters: {'eta': 0.2934017906167348, 'max_depth': 3, 'gamma': 6.878891460823116e-06, 'subsample': 0.9976851041867044, 'colsample_bytree': 0.9968922725325938, 'booster': 'gbtree'}. Best is trial 25 with value: 67.4505798.
# [I 2023-06-07 10:51:11,453] Trial 27 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:51:14,088] Trial 28 finished with value: 68.350889 and parameters: {'eta': 0.3944902354648065, 'max_depth': 3, 'gamma': 4.141958319848749e-05, 'subsample': 0.9408419776119319, 'colsample_bytree': 0.903823097239404, 'booster': 'gbtree'}. Best is trial 25 with value: 67.4505798.
# [I 2023-06-07 10:51:15,295] Trial 29 pruned. Trial was pruned at iteration 21.
# [I 2023-06-07 10:51:20,780] Trial 30 finished with value: 68.2364518 and parameters: {'eta': 0.15377992938050888, 'max_depth': 2, 'gamma': 0.00047540567524303383, 'subsample': 0.8521690838103252, 'colsample_bytree': 0.8950505161760053, 'booster': 'gbtree'}. Best is trial 25 with value: 67.4505798.
# [I 2023-06-07 10:51:23,565] Trial 31 finished with value: 68.9339304 and parameters: {'eta': 0.4009944074530236, 'max_depth': 3, 'gamma': 0.00035889757222567196, 'subsample': 0.9570204225355197, 'colsample_bytree': 0.8970228380851175, 'booster': 'gbtree'}. Best is trial 25 with value: 67.4505798.
# [I 2023-06-07 10:51:27,242] Trial 32 finished with value: 68.26519479999999 and parameters: {'eta': 0.26550004147599693, 'max_depth': 3, 'gamma': 0.0013142208849774792, 'subsample': 0.9614882420061786, 'colsample_bytree': 0.9282409160973127, 'booster': 'gbtree'}. Best is trial 25 with value: 67.4505798.
# [I 2023-06-07 10:51:31,463] Trial 33 finished with value: 68.6970306 and parameters: {'eta': 0.22154326159301188, 'max_depth': 5, 'gamma': 0.00014813132214655476, 'subsample': 0.998125111233115, 'colsample_bytree': 0.8630881216832995, 'booster': 'gbtree'}. Best is trial 25 with value: 67.4505798.
# [I 2023-06-07 10:51:34,439] Trial 34 finished with value: 66.53135660000001 and parameters: {'eta': 0.49394389045721004, 'max_depth': 2, 'gamma': 0.009156985953962728, 'subsample': 0.9090635714439531, 'colsample_bytree': 0.9561633862743839, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:51:37,094] Trial 35 finished with value: 69.4511368 and parameters: {'eta': 0.42903700956193674, 'max_depth': 2, 'gamma': 0.01538349142007372, 'subsample': 0.9095382606421246, 'colsample_bytree': 0.9298980577897484, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:51:38,406] Trial 36 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:51:40,642] Trial 37 finished with value: 69.9468018 and parameters: {'eta': 0.5711377651167661, 'max_depth': 4, 'gamma': 0.007186473696269498, 'subsample': 0.8788981510741352, 'colsample_bytree': 0.9704942901599773, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:51:43,105] Trial 38 finished with value: 74.819603 and parameters: {'eta': 0.5741966509367652, 'max_depth': 3, 'gamma': 2.654686489318383e-05, 'subsample': 0.9473672946307667, 'colsample_bytree': 0.7543635892047302, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:51:48,053] Trial 39 finished with value: 68.0397356 and parameters: {'eta': 0.1897642217027256, 'max_depth': 2, 'gamma': 0.00150315706859849, 'subsample': 0.8672790932384591, 'colsample_bytree': 0.8527998281087399, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:51:53,508] Trial 40 finished with value: 69.583506 and parameters: {'eta': 0.15701146343808478, 'max_depth': 10, 'gamma': 4.342578859678176e-06, 'subsample': 0.9269206228486575, 'colsample_bytree': 0.9504115260927394, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:51:55,993] Trial 41 finished with value: 69.323571 and parameters: {'eta': 0.961694697112177, 'max_depth': 2, 'gamma': 0.001567688180777352, 'subsample': 0.8447402938376936, 'colsample_bytree': 0.849106890900459, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:01,318] Trial 42 finished with value: 72.83807540000001 and parameters: {'eta': 0.19788104817326413, 'max_depth': 1, 'gamma': 0.0001349225418929564, 'subsample': 0.8962391461788934, 'colsample_bytree': 0.8673086576116721, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:04,086] Trial 43 finished with value: 67.9950852 and parameters: {'eta': 0.5490742417557938, 'max_depth': 2, 'gamma': 0.000773548155833788, 'subsample': 0.9567881078859862, 'colsample_bytree': 0.9123815854842343, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:06,688] Trial 44 finished with value: 69.015674 and parameters: {'eta': 0.540321725773487, 'max_depth': 4, 'gamma': 0.000644858750166495, 'subsample': 0.962739704651203, 'colsample_bytree': 0.9991642636972788, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:09,118] Trial 45 finished with value: 68.459311 and parameters: {'eta': 0.42115779915208656, 'max_depth': 3, 'gamma': 5.325202903775136e-05, 'subsample': 0.9085941266146235, 'colsample_bytree': 0.9200744926883124, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:11,530] Trial 46 finished with value: 70.1829896 and parameters: {'eta': 0.968719132449576, 'max_depth': 2, 'gamma': 0.008967144005647076, 'subsample': 0.9619422651883279, 'colsample_bytree': 0.9483994380171402, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:16,488] Trial 47 finished with value: 68.4569618 and parameters: {'eta': 0.2811338631799282, 'max_depth': 2, 'gamma': 0.00020783755865098305, 'subsample': 0.8895956249899849, 'colsample_bytree': 0.8170112701896844, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:17,637] Trial 48 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:52:20,753] Trial 49 finished with value: 71.2191712 and parameters: {'eta': 0.6338463979269042, 'max_depth': 1, 'gamma': 2.4138107502565147e-05, 'subsample': 0.9709309786722714, 'colsample_bytree': 0.9690811244711249, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:21,849] Trial 50 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:52:27,315] Trial 51 finished with value: 68.30523459999999 and parameters: {'eta': 0.17561566274675844, 'max_depth': 2, 'gamma': 0.001871858935935208, 'subsample': 0.8774900043726287, 'colsample_bytree': 0.9198680035601109, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:28,450] Trial 52 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:52:31,244] Trial 53 finished with value: 67.697425 and parameters: {'eta': 0.34546495908049446, 'max_depth': 3, 'gamma': 0.0002809704293382193, 'subsample': 0.944731491975754, 'colsample_bytree': 0.8701749447211206, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:33,523] Trial 54 finished with value: 73.33488220000001 and parameters: {'eta': 0.6825843350511056, 'max_depth': 3, 'gamma': 0.0002670206644583471, 'subsample': 0.9663508266666626, 'colsample_bytree': 0.8292429150360997, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:36,728] Trial 55 finished with value: 69.43674680000001 and parameters: {'eta': 0.29023147037303854, 'max_depth': 5, 'gamma': 0.003921703008368747, 'subsample': 0.9330474069924912, 'colsample_bytree': 0.8891013083422407, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:38,323] Trial 56 pruned. Trial was pruned at iteration 27.
# [I 2023-06-07 10:52:39,501] Trial 57 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:52:40,765] Trial 58 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:52:42,026] Trial 59 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:52:43,236] Trial 60 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:52:48,333] Trial 61 finished with value: 68.4664276 and parameters: {'eta': 0.1991431202668494, 'max_depth': 2, 'gamma': 0.0025199481257083297, 'subsample': 0.8666263386250239, 'colsample_bytree': 0.8571721838671558, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:52,037] Trial 62 finished with value: 66.80630099999999 and parameters: {'eta': 0.3312368220829161, 'max_depth': 3, 'gamma': 0.0013234022146555442, 'subsample': 0.9693150507714345, 'colsample_bytree': 0.8373634356427238, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:54,496] Trial 63 finished with value: 69.4818664 and parameters: {'eta': 0.5748841084778075, 'max_depth': 3, 'gamma': 0.0002378151729851644, 'subsample': 0.9724382791029269, 'colsample_bytree': 0.9813880827904425, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:52:58,005] Trial 64 finished with value: 68.77566680000001 and parameters: {'eta': 0.31124776000983684, 'max_depth': 3, 'gamma': 0.000756729579322405, 'subsample': 0.9314529195522965, 'colsample_bytree': 0.9470841682373765, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:53:00,941] Trial 65 finished with value: 68.442668 and parameters: {'eta': 0.38003794975498273, 'max_depth': 3, 'gamma': 0.00013389885788504314, 'subsample': 0.9490900610362617, 'colsample_bytree': 0.8943849779196384, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:53:02,366] Trial 66 pruned. Trial was pruned at iteration 24.
# [I 2023-06-07 10:53:04,797] Trial 67 finished with value: 68.6416328 and parameters: {'eta': 0.7203895651311878, 'max_depth': 5, 'gamma': 0.0028515023349209912, 'subsample': 0.9708733397187691, 'colsample_bytree': 0.9174786169610988, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:53:05,999] Trial 68 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:07,181] Trial 69 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:09,599] Trial 70 finished with value: 69.5628958 and parameters: {'eta': 0.4857120060117547, 'max_depth': 3, 'gamma': 0.0006062077611615214, 'subsample': 0.8894772442890523, 'colsample_bytree': 0.8810185483036275, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:53:10,772] Trial 71 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:13,984] Trial 72 finished with value: 67.7480964 and parameters: {'eta': 0.3445053362346134, 'max_depth': 2, 'gamma': 0.0012380576883973084, 'subsample': 0.8676137854510018, 'colsample_bytree': 0.9413458691864656, 'booster': 'gbtree'}. Best is trial 34 with value: 66.53135660000001.
# [I 2023-06-07 10:53:17,852] Trial 73 finished with value: 66.0929402 and parameters: {'eta': 0.3020077427729937, 'max_depth': 2, 'gamma': 0.0009824159298840688, 'subsample': 0.978686211135614, 'colsample_bytree': 0.9397594010187873, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:20,901] Trial 74 finished with value: 68.4688988 and parameters: {'eta': 0.2612605918919632, 'max_depth': 3, 'gamma': 0.001206758634732364, 'subsample': 0.976283040036289, 'colsample_bytree': 0.9424710636192845, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:22,084] Trial 75 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:24,631] Trial 76 finished with value: 71.435152 and parameters: {'eta': 0.722435230116923, 'max_depth': 2, 'gamma': 0.0003028981393144467, 'subsample': 0.9850229896804213, 'colsample_bytree': 0.9513049586342526, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:27,698] Trial 77 finished with value: 67.6504766 and parameters: {'eta': 0.3303113815342093, 'max_depth': 3, 'gamma': 0.001240218084855849, 'subsample': 0.860205782748245, 'colsample_bytree': 0.9309236166499102, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:28,901] Trial 78 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:31,623] Trial 79 finished with value: 68.11337900000001 and parameters: {'eta': 0.4762313420699748, 'max_depth': 3, 'gamma': 0.006034989143566137, 'subsample': 0.8970341976631528, 'colsample_bytree': 0.9253847791961427, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:35,882] Trial 80 finished with value: 66.11211 and parameters: {'eta': 0.3079486914624873, 'max_depth': 2, 'gamma': 4.953166593454274e-05, 'subsample': 0.8742166958263582, 'colsample_bytree': 0.9576750630242716, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:38,444] Trial 81 finished with value: 68.12423399999999 and parameters: {'eta': 0.3534499731145663, 'max_depth': 2, 'gamma': 6.743486991004354e-05, 'subsample': 0.8727292883135663, 'colsample_bytree': 0.9616159670439796, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:39,615] Trial 82 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:40,917] Trial 83 pruned. Trial was pruned at iteration 23.
# [I 2023-06-07 10:53:42,066] Trial 84 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:44,475] Trial 85 finished with value: 69.4065484 and parameters: {'eta': 0.33896256220532534, 'max_depth': 3, 'gamma': 0.00011921599563065511, 'subsample': 0.8617318987370431, 'colsample_bytree': 0.9831137745898147, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:45,686] Trial 86 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:48,852] Trial 87 finished with value: 66.261465 and parameters: {'eta': 0.4723329774415892, 'max_depth': 2, 'gamma': 0.00020590154689875643, 'subsample': 0.9399374729915615, 'colsample_bytree': 0.9380775450682852, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:49,932] Trial 88 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:53:51,806] Trial 89 finished with value: 69.89468780000001 and parameters: {'eta': 0.6912539951462727, 'max_depth': 3, 'gamma': 5.192062692369746e-05, 'subsample': 0.9033609159547404, 'colsample_bytree': 0.9997987540685949, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:54,260] Trial 90 finished with value: 67.70006339999999 and parameters: {'eta': 0.471463448409065, 'max_depth': 6, 'gamma': 1.5404105934287628e-05, 'subsample': 0.9807733900176121, 'colsample_bytree': 0.9342871123753486, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:56,760] Trial 91 finished with value: 69.8068472 and parameters: {'eta': 0.47302909137949345, 'max_depth': 6, 'gamma': 2.8340135642093687e-05, 'subsample': 0.9547799124061159, 'colsample_bytree': 0.9305900521065911, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:53:57,920] Trial 92 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:54:00,130] Trial 93 finished with value: 68.3601464 and parameters: {'eta': 0.5868068315670625, 'max_depth': 7, 'gamma': 1.0924122135605822e-05, 'subsample': 0.9323719137333017, 'colsample_bytree': 0.904542987568289, 'booster': 'gbtree'}. Best is trial 73 with value: 66.0929402.
# [I 2023-06-07 10:54:01,318] Trial 94 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 10:54:02,557] Trial 95 pruned. Trial was pruned at iteration 20.
#
# Hyper-Parameter Optimization successfully finished.
#   Number of finished trials:  96
#   Best trial:
#     Value: 66.0929402
#     Params:
#     eta: 0.3020077427729937
#     max_depth: 2
#     gamma: 0.0009824159298840688
#     subsample: 0.978686211135614
#     colsample_bytree: 0.9397594010187873
#     booster: gbtree
#     opt_rounds: 47

# %% [markdown]
# # Model Training

# %%
np.random.seed(123)

opt_params = opt_param.copy()
n_rounds = opt_params["opt_rounds"]
del opt_params["opt_rounds"]

# Train Model with optimized hyperparameters
xgblss.train(opt_params,
             dtrain,
             num_boost_round=n_rounds
             )

# %% [markdown]
# # Prediction

# %%
# Set seed for reproducibility
torch.manual_seed(123)

# Number of samples to draw from predicted distribution
n_samples = 1000
# Quantiles to calculate from predicted distribution
quant_sel = [0.05, 0.95] 

# Sample from predicted distribution
pred_samples = xgblss.predict(dtest,
                              pred_type="samples",
                              n_samples=n_samples,
                              seed=123)

# Calculate quantiles from predicted distribution
pred_quantiles = xgblss.predict(dtest,
                                pred_type="quantiles",
                                n_samples=n_samples,
                                quantiles=quant_sel)

# Returns predicted distributional parameters
pred_params = xgblss.predict(dtest,
                             pred_type="parameters")

# %%
pred_samples.head()
# Out:
#    y_sample0  y_sample1  y_sample2  y_sample3  y_sample4  y_sample5
# 0          4          4          6          3          1          8  \
# 1          0          0          0          0          0          0
# 2         30         38         38         32         32         33
# 3         35         25         27         29         21         23
# 4          4          4          2          0          4          4
#
#    y_sample6  y_sample7  y_sample8  y_sample9  ...  y_sample990  y_sample991
# 0          4          0          1          2  ...            4            2  \
# 1          0          0          0          0  ...            0            0
# 2         33         17         21         39  ...           27           47
# 3         27         35         34         15  ...           27           33
# 4          4          4          2          4  ...            2            3
#
#    y_sample992  y_sample993  y_sample994  y_sample995  y_sample996
# 0            3            3            1            3            3  \
# 1            0            0            0            0            0
# 2           28           25           28           25           36
# 3           34           33           35           29           31
# 4            7            1            2            3            1
#
#    y_sample997  y_sample998  y_sample999
# 0            5            5            3
# 1            0            0            0
# 2           22           29           23
# 3           29           27           28
# 4            3            4            6
#
# [5 rows x 1000 columns]

# %%
pred_quantiles.head()
# Out:
#    quant_0.05  quant_0.95
# 0           1           8
# 1           0           0
# 2          21          39
# 3          22          39
# 4           0           6

# %%
pred_params.head()
# Out:
#         rate      gate
# 0   4.426682  0.002607
# 1   0.028917  0.977742
# 2  30.184778  0.001371
# 3  30.211044  0.001196
# 4   3.188997  0.006165

# %% [markdown]
# # SHAP Interpretability

# %%
# Partial Dependence Plot of rate parameter
xgblss.plot(X_test,
            parameter="rate",
            feature="persons",
            plot_type="Partial_Dependence")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# Feature Importance of gate parameter
xgblss.plot(X_test,
            parameter="gate",
            plot_type="Feature_Importance")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # Density Plots of Actual and Predicted Samples

# %%
pred_df = pd.melt(pred_samples.iloc[:,0:5])
actual_df = pd.DataFrame.from_dict({"variable": "ACTUAL", "value": y_test.reshape(-1,)})
plot_df = pd.concat([pred_df, actual_df])

(
    ggplot(plot_df, 
           aes(x="value",
               color="variable",
               fill="variable")) +  
    geom_density(alpha=0.4) + 
    facet_wrap("variable",
              scales="free_y",
              ncol=2) + 
    theme_bw(base_size=15) + 
    theme(legend_position="none")
)
# Out:
# <Figure Size: (1800 x 900)>
