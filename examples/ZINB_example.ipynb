# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/StatMixedML/XGBoostLSS/blob/master/examples/ZINB_example.ipynb)

# %% [markdown]
# # Imports

# %%
from xgboostlss.model import *
from xgboostlss.distributions.ZINB import *

from sklearn.model_selection import train_test_split
import pandas as pd
import multiprocessing
import plotnine
from plotnine import *
plotnine.options.figure_size = (18, 9)
n_cpu = multiprocessing.cpu_count()

# %% [markdown]
# # Data

# %%
# For more information on the dataset see: https://stats.oarc.ucla.edu/stata/dae/zero-inflated-poisson-regression/
data = pd.read_stata("http://www.stata-press.com/data/r10/fish.dta")
y = data["count"].values.reshape(-1,1)
X = data.drop(columns="count")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

dtrain = xgb.DMatrix(X_train, label=y_train, nthread=n_cpu)
dtest = xgb.DMatrix(X_test, nthread=n_cpu)

# %% [markdown]
# # Distribution Selection

# %%
# Specifies Zero-Inflated Negative Binomial distribution. See ?ZINB for an overview.
xgblss = XGBoostLSS(
    ZINB(stabilization="None",              # Options are "None", "MAD", "L2".
         response_fn_total_count="relu",    # Function to transform the total_count-parameter, e.g., "exp", "softplus" or "relu".
         response_fn_probs="sigmoid",       # Function to transform the probs-parameter, e.g., "sigmoid",
         loss_fn="nll"                      # Function to transform the concentration and rate parameters, e.g., "exp" or "softplus".
        )
)

# %% [markdown]
# # Hyper-Parameter Optimization

# %%
# Any XGBoost hyperparameter can be tuned, where the structure of the parameter dictionary needs to be as follows:

    # Float/Int sample_type
        # {"param_name": ["sample_type", low, high, log]}
            # sample_type: str, Type of sampling, e.g., "float" or "int"
            # low: int, Lower endpoint of the range of suggested values
            # high: int, Upper endpoint of the range of suggested values
            # log: bool, Flag to sample the value from the log domain or not
        # Example: {"eta": "float", low=1e-5, high=1, log=True]}

    # Categorical sample_type
        # {"param_name": ["sample_type", ["choice1", "choice2", "choice3", "..."]]}
            # sample_type: str, Type of sampling, either "categorical"
            # choice1, choice2, choice3, ...: str, Possible choices for the parameter
        # Example: {"booster": ["categorical", ["gbtree", "dart"]]}

    # For parameters without tunable choice (this is needed if tree_method = "gpu_hist" and gpu_id needs to be specified)
        # {"param_name": ["none", [value]]},
            # param_name: str, Name of the parameter
            # value: int, Value of the parameter
        # Example: {"gpu_id": ["none", [0]]}

# Depending on which parameters are optimized, it might happen that some of them are not used, e.g., when {"booster":  ["categorical", ["gbtree", "gblinear"]]} and {"max_depth": ["int", 1, 10, False]} are
# specified, max_depth is not used when gblinear is sampled, since it has no such argument.

param_dict = {
    "eta":              ["float", {"low": 1e-5,   "high": 1,     "log": True}],
    "max_depth":        ["int",   {"low": 1,      "high": 10,    "log": False}],
    "gamma":            ["float", {"low": 1e-8,   "high": 40,    "log": True}],
    "subsample":        ["float", {"low": 0.2,    "high": 1.0,   "log": False}],
    "colsample_bytree": ["float", {"low": 0.2,    "high": 1.0,   "log": False}],
    "booster":          ["categorical", ["gbtree"]],
    # "tree_method":    ["categorical", ["auto", "approx", "hist", "gpu_hist"]],
    # "gpu_id":         ["none", [0]]
}

np.random.seed(123)
opt_param = xgblss.hyper_opt(param_dict,
                             dtrain,
                             num_boost_round=100,        # Number of boosting iterations.
                             nfold=5,                    # Number of cv-folds.
                             early_stopping_rounds=20,   # Number of early-stopping rounds
                             max_minutes=5,              # Time budget in minutes, i.e., stop study after the given number of minutes.
                             n_trials=None,              # The number of trials. If this argument is set to None, there is no limitation on the number of trials.
                             silence=False,              # Controls the verbosity of the trail, i.e., user can silence the outputs of the trail.
                             seed=123,                   # Seed used to generate cv-folds.
                             hp_seed=None                # Seed for random number generator used in the Bayesian hyperparameter search.
                            )
# Out:
# [I 2023-06-07 12:38:45,718] A new study created in memory with name: XGBoostLSS Hyper-Parameter Optimization
# C:\Users\maerzale\.virtualenvs\XGBoostLSS-vIPRRz-M\lib\site-packages\optuna\progress_bar.py:56: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#    0%|          | 00:00/05:00
# [I 2023-06-07 12:38:53,933] Trial 0 finished with value: 51.3298042 and parameters: {'eta': 0.09562234136471845, 'max_depth': 6, 'gamma': 13.540543596250464, 'subsample': 0.8006389207622857, 'colsample_bytree': 0.3755703066294756, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:00,738] Trial 1 finished with value: 72.24673779999999 and parameters: {'eta': 0.00027242168941223125, 'max_depth': 9, 'gamma': 1.3607771577838245e-08, 'subsample': 0.45141397773770575, 'colsample_bytree': 0.5818447204495911, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:07,449] Trial 2 finished with value: 69.5676702 and parameters: {'eta': 0.0024451836582500344, 'max_depth': 9, 'gamma': 2.668468768851761e-05, 'subsample': 0.8777775418800031, 'colsample_bytree': 0.5252011335389215, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:14,610] Trial 3 finished with value: 70.2596748 and parameters: {'eta': 0.0019621001578217574, 'max_depth': 9, 'gamma': 3.070415795978299e-05, 'subsample': 0.7285226623677774, 'colsample_bytree': 0.4885266634755938, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:22,419] Trial 4 finished with value: 53.965029400000006 and parameters: {'eta': 0.05553082820555649, 'max_depth': 5, 'gamma': 0.45440308546005564, 'subsample': 0.8264617219591814, 'colsample_bytree': 0.24116569137323118, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:29,648] Trial 5 finished with value: 70.8458464 and parameters: {'eta': 0.0022755502745689616, 'max_depth': 1, 'gamma': 5.051004088491689, 'subsample': 0.9221460020194285, 'colsample_bytree': 0.30953695457884706, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:36,431] Trial 6 finished with value: 71.73478699999998 and parameters: {'eta': 0.0006193498622208788, 'max_depth': 2, 'gamma': 3.345436328534125e-08, 'subsample': 0.5114475166393906, 'colsample_bytree': 0.8526962357023347, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:42,945] Trial 7 finished with value: 69.0143418 and parameters: {'eta': 0.012089008552214566, 'max_depth': 2, 'gamma': 0.0016015956702012135, 'subsample': 0.29542229952941057, 'colsample_bytree': 0.23367841255897304, 'booster': 'gbtree'}. Best is trial 0 with value: 51.3298042.
# [I 2023-06-07 12:39:46,582] Trial 8 finished with value: 46.2553488 and parameters: {'eta': 0.33127855304045495, 'max_depth': 9, 'gamma': 7.357702033465214e-05, 'subsample': 0.7663267532272127, 'colsample_bytree': 0.5357972612956758, 'booster': 'gbtree'}. Best is trial 8 with value: 46.2553488.
# [I 2023-06-07 12:39:53,325] Trial 9 finished with value: 71.00442960000001 and parameters: {'eta': 0.00284347138264469, 'max_depth': 4, 'gamma': 1.3099278159352927e-05, 'subsample': 0.9063233701493478, 'colsample_bytree': 0.2232640853099479, 'booster': 'gbtree'}. Best is trial 8 with value: 46.2553488.
# [I 2023-06-07 12:39:55,528] Trial 10 finished with value: 48.8044176 and parameters: {'eta': 0.7168671443351086, 'max_depth': 7, 'gamma': 0.01473571349637949, 'subsample': 0.6555358845154075, 'colsample_bytree': 0.7852564299471179, 'booster': 'gbtree'}. Best is trial 8 with value: 46.2553488.
# [I 2023-06-07 12:39:58,970] Trial 11 finished with value: 44.5149376 and parameters: {'eta': 0.5655299301610619, 'max_depth': 7, 'gamma': 0.01297198955968597, 'subsample': 0.666715283773936, 'colsample_bytree': 0.7421144515278774, 'booster': 'gbtree'}. Best is trial 11 with value: 44.5149376.
# [I 2023-06-07 12:40:01,232] Trial 12 finished with value: 47.64123360000001 and parameters: {'eta': 0.782467638093458, 'max_depth': 7, 'gamma': 0.024266772440940308, 'subsample': 0.6559756399553683, 'colsample_bytree': 0.7427716483763933, 'booster': 'gbtree'}. Best is trial 11 with value: 44.5149376.
# [I 2023-06-07 12:40:02,800] Trial 13 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:40:09,501] Trial 14 finished with value: 39.18710180000001 and parameters: {'eta': 0.167214108899319, 'max_depth': 7, 'gamma': 0.1471689525569623, 'subsample': 0.7183920367375637, 'colsample_bytree': 0.9954413997531097, 'booster': 'gbtree'}. Best is trial 14 with value: 39.18710180000001.
# [I 2023-06-07 12:40:16,361] Trial 15 finished with value: 42.236235199999996 and parameters: {'eta': 0.0601874617340442, 'max_depth': 7, 'gamma': 0.8268953201391317, 'subsample': 0.5759301266159614, 'colsample_bytree': 0.9616221732904052, 'booster': 'gbtree'}. Best is trial 14 with value: 39.18710180000001.
# [I 2023-06-07 12:40:23,168] Trial 16 finished with value: 44.2350992 and parameters: {'eta': 0.04685594505031184, 'max_depth': 4, 'gamma': 0.8651544369840437, 'subsample': 0.537828772512271, 'colsample_bytree': 0.9925503895604602, 'booster': 'gbtree'}. Best is trial 14 with value: 39.18710180000001.
# [I 2023-06-07 12:40:24,680] Trial 17 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:40:31,914] Trial 18 finished with value: 38.860203 and parameters: {'eta': 0.15464709609435198, 'max_depth': 8, 'gamma': 0.3781008779410396, 'subsample': 0.4156450853572201, 'colsample_bytree': 0.8963548287700153, 'booster': 'gbtree'}. Best is trial 18 with value: 38.860203.
# [I 2023-06-07 12:40:39,307] Trial 19 finished with value: 39.416608999999994 and parameters: {'eta': 0.1599003026075848, 'max_depth': 8, 'gamma': 0.1308741305642985, 'subsample': 0.41595678426221794, 'colsample_bytree': 0.8828264713246176, 'booster': 'gbtree'}. Best is trial 18 with value: 38.860203.
# [I 2023-06-07 12:40:46,463] Trial 20 finished with value: 39.194989 and parameters: {'eta': 0.22376243779145852, 'max_depth': 5, 'gamma': 2.6315381790349828, 'subsample': 0.22120970499110829, 'colsample_bytree': 0.8889826838387047, 'booster': 'gbtree'}. Best is trial 18 with value: 38.860203.
# [I 2023-06-07 12:40:53,264] Trial 21 finished with value: 40.758237199999996 and parameters: {'eta': 0.21468016620386035, 'max_depth': 5, 'gamma': 4.067564906544461, 'subsample': 0.2482879191055883, 'colsample_bytree': 0.9135547589604974, 'booster': 'gbtree'}. Best is trial 18 with value: 38.860203.
# [I 2023-06-07 12:41:00,149] Trial 22 finished with value: 39.999778000000006 and parameters: {'eta': 0.23744403582028062, 'max_depth': 4, 'gamma': 0.16465226209456021, 'subsample': 0.2025588591828502, 'colsample_bytree': 0.8589940345896415, 'booster': 'gbtree'}. Best is trial 18 with value: 38.860203.
# [I 2023-06-07 12:41:03,792] Trial 23 finished with value: 45.72364420000001 and parameters: {'eta': 0.9711425559253654, 'max_depth': 8, 'gamma': 4.22934477895556, 'subsample': 0.3454350715568731, 'colsample_bytree': 0.9266176816450864, 'booster': 'gbtree'}. Best is trial 18 with value: 38.860203.
# [I 2023-06-07 12:41:05,268] Trial 24 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:12,520] Trial 25 finished with value: 38.449906000000006 and parameters: {'eta': 0.16997401020148606, 'max_depth': 6, 'gamma': 2.1268099185785467, 'subsample': 0.40025637000892333, 'colsample_bytree': 0.9258095239245668, 'booster': 'gbtree'}. Best is trial 25 with value: 38.449906000000006.
# [I 2023-06-07 12:41:14,077] Trial 26 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:15,643] Trial 27 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:17,194] Trial 28 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:18,744] Trial 29 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:20,292] Trial 30 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:27,294] Trial 31 finished with value: 38.663845 and parameters: {'eta': 0.24215339182015383, 'max_depth': 5, 'gamma': 1.4640784596922913, 'subsample': 0.28752669729470065, 'colsample_bytree': 0.8927213026349515, 'booster': 'gbtree'}. Best is trial 25 with value: 38.449906000000006.
# [I 2023-06-07 12:41:34,848] Trial 32 finished with value: 39.673024 and parameters: {'eta': 0.3763380114861125, 'max_depth': 5, 'gamma': 1.8631040225133229, 'subsample': 0.27332163548501065, 'colsample_bytree': 0.850267863858084, 'booster': 'gbtree'}. Best is trial 25 with value: 38.449906000000006.
# [I 2023-06-07 12:41:42,281] Trial 33 finished with value: 40.307466 and parameters: {'eta': 0.4140702360662635, 'max_depth': 3, 'gamma': 1.8174778617432803, 'subsample': 0.3181135656759633, 'colsample_bytree': 0.9523960661077764, 'booster': 'gbtree'}. Best is trial 25 with value: 38.449906000000006.
# [I 2023-06-07 12:41:43,798] Trial 34 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:45,299] Trial 35 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:46,737] Trial 36 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:48,209] Trial 37 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:49,704] Trial 38 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:51,483] Trial 39 pruned. Trial was pruned at iteration 25.
# [I 2023-06-07 12:41:52,929] Trial 40 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:41:59,608] Trial 41 finished with value: 40.091398600000005 and parameters: {'eta': 0.2213216779509951, 'max_depth': 5, 'gamma': 2.037587008593295, 'subsample': 0.20651818783917217, 'colsample_bytree': 0.9070223662899319, 'booster': 'gbtree'}. Best is trial 25 with value: 38.449906000000006.
# [I 2023-06-07 12:42:06,587] Trial 42 finished with value: 38.665284799999995 and parameters: {'eta': 0.2643746085225048, 'max_depth': 5, 'gamma': 2.4206227375489515, 'subsample': 0.23347685377368194, 'colsample_bytree': 0.8768073346418055, 'booster': 'gbtree'}. Best is trial 25 with value: 38.449906000000006.
# [I 2023-06-07 12:42:11,573] Trial 43 finished with value: 40.0031194 and parameters: {'eta': 0.5169617479293654, 'max_depth': 4, 'gamma': 0.4992496325452744, 'subsample': 0.25812848139168754, 'colsample_bytree': 0.96510780930801, 'booster': 'gbtree'}. Best is trial 25 with value: 38.449906000000006.
# [I 2023-06-07 12:42:13,017] Trial 44 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:14,544] Trial 45 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:16,062] Trial 46 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:23,008] Trial 47 finished with value: 37.5343692 and parameters: {'eta': 0.28472094030572037, 'max_depth': 4, 'gamma': 1.0794717507710752, 'subsample': 0.2810123446211498, 'colsample_bytree': 0.7805511556904254, 'booster': 'gbtree'}. Best is trial 47 with value: 37.5343692.
# [I 2023-06-07 12:42:26,418] Trial 48 pruned. Trial was pruned at iteration 49.
# [I 2023-06-07 12:42:27,883] Trial 49 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:29,419] Trial 50 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:36,453] Trial 51 finished with value: 39.728880399999994 and parameters: {'eta': 0.2801124485100722, 'max_depth': 5, 'gamma': 0.8639341241713719, 'subsample': 0.7301291154150936, 'colsample_bytree': 0.8737201316715183, 'booster': 'gbtree'}. Best is trial 47 with value: 37.5343692.
# [I 2023-06-07 12:42:37,997] Trial 52 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:40,223] Trial 53 pruned. Trial was pruned at iteration 31.
# [I 2023-06-07 12:42:43,903] Trial 54 pruned. Trial was pruned at iteration 51.
# [I 2023-06-07 12:42:51,324] Trial 55 finished with value: 39.490005000000004 and parameters: {'eta': 0.29190615209820636, 'max_depth': 5, 'gamma': 0.8206007344954416, 'subsample': 0.3676032080555074, 'colsample_bytree': 0.8395589418497931, 'booster': 'gbtree'}. Best is trial 47 with value: 37.5343692.
# [I 2023-06-07 12:42:52,955] Trial 56 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:55,201] Trial 57 pruned. Trial was pruned at iteration 31.
# [I 2023-06-07 12:42:56,821] Trial 58 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:42:58,402] Trial 59 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:43:03,571] Trial 60 finished with value: 39.8762222 and parameters: {'eta': 0.27548217072030906, 'max_depth': 6, 'gamma': 0.02736700278537602, 'subsample': 0.3533598914586932, 'colsample_bytree': 0.8554888604626292, 'booster': 'gbtree'}. Best is trial 47 with value: 37.5343692.
# [I 2023-06-07 12:43:05,065] Trial 61 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:43:06,536] Trial 62 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:43:08,044] Trial 63 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:43:09,517] Trial 64 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:43:14,724] Trial 65 finished with value: 39.8020118 and parameters: {'eta': 0.33941781921749664, 'max_depth': 6, 'gamma': 0.09169093249196998, 'subsample': 0.25625358518700814, 'colsample_bytree': 0.8707675969774606, 'booster': 'gbtree'}. Best is trial 47 with value: 37.5343692.
# [I 2023-06-07 12:43:16,255] Trial 66 pruned. Trial was pruned at iteration 20.
# [I 2023-06-07 12:43:23,225] Trial 67 finished with value: 37.077009600000004 and parameters: {'eta': 0.23187667119222302, 'max_depth': 7, 'gamma': 1.2249146053301139, 'subsample': 0.401854633584047, 'colsample_bytree': 0.9390564773774654, 'booster': 'gbtree'}. Best is trial 67 with value: 37.077009600000004.
# [I 2023-06-07 12:43:30,031] Trial 68 finished with value: 39.1900628 and parameters: {'eta': 0.15381274010734233, 'max_depth': 7, 'gamma': 0.20843171670862506, 'subsample': 0.40353257010293997, 'colsample_bytree': 0.9474123795144574, 'booster': 'gbtree'}. Best is trial 67 with value: 37.077009600000004.
# [I 2023-06-07 12:43:36,703] Trial 69 finished with value: 37.698992999999994 and parameters: {'eta': 0.436296446920762, 'max_depth': 8, 'gamma': 1.0389106892853128, 'subsample': 0.4393007515607069, 'colsample_bytree': 0.9768882593651884, 'booster': 'gbtree'}. Best is trial 67 with value: 37.077009600000004.
# [I 2023-06-07 12:43:43,427] Trial 70 finished with value: 37.722933999999995 and parameters: {'eta': 0.40442092509360406, 'max_depth': 8, 'gamma': 1.420402773966077, 'subsample': 0.4456403818538282, 'colsample_bytree': 0.9480175125186738, 'booster': 'gbtree'}. Best is trial 67 with value: 37.077009600000004.
# [I 2023-06-07 12:43:50,332] Trial 71 finished with value: 38.083817599999996 and parameters: {'eta': 0.45617412282861336, 'max_depth': 8, 'gamma': 1.0688368681913047, 'subsample': 0.4505914615705199, 'colsample_bytree': 0.9482273288901174, 'booster': 'gbtree'}. Best is trial 67 with value: 37.077009600000004.
#
# Hyper-Parameter Optimization successfully finished.
#   Number of finished trials:  72
#   Best trial:
#     Value: 37.077009600000004
#     Params:
#     eta: 0.23187667119222302
#     max_depth: 7
#     gamma: 1.2249146053301139
#     subsample: 0.401854633584047
#     colsample_bytree: 0.9390564773774654
#     booster: gbtree
#     opt_rounds: 98

# %% [markdown]
# # Model Training

# %%
np.random.seed(123)

opt_params = opt_param.copy()
n_rounds = opt_params["opt_rounds"]
del opt_params["opt_rounds"]

# Train Model with optimized hyperparameters
xgblss.train(opt_params,
             dtrain,
             num_boost_round=n_rounds
             )

# %% [markdown]
# # Prediction

# %%
# Set seed for reproducibility
torch.manual_seed(123)

# Number of samples to draw from predicted distribution
n_samples = 1000
# Quantiles to calculate from predicted distribution
quant_sel = [0.05, 0.95] 

# Sample from predicted distribution
pred_samples = xgblss.predict(dtest,
                              pred_type="samples",
                              n_samples=n_samples,
                              seed=123)

# Calculate quantiles from predicted distribution
pred_quantiles = xgblss.predict(dtest,
                                pred_type="quantiles",
                                n_samples=n_samples,
                                quantiles=quant_sel)

# Returns predicted distributional parameters
pred_params = xgblss.predict(dtest,
                             pred_type="parameters")

# %%
pred_samples.head()
# Out:
#    y_sample0  y_sample1  y_sample2  y_sample3  y_sample4  y_sample5
# 0          2          2          8          5          3          8  \
# 1          0          0          0          0          0          0
# 2          8         17         32         68         38         57
# 3         37         62         40         37         37         54
# 4          0          1          1          1          0          0
#
#    y_sample6  y_sample7  y_sample8  y_sample9  ...  y_sample990  y_sample991
# 0          4          6          6          2  ...            1            5  \
# 1          0          0          0          0  ...            0            0
# 2         37         22         22         24  ...           28           56
# 3         22         18         83         40  ...           35           22
# 4          2          1          2          1  ...            2            0
#
#    y_sample992  y_sample993  y_sample994  y_sample995  y_sample996
# 0            4           10            2            5            7  \
# 1            0            0            0            0            0
# 2           69           30           24           18           50
# 3           26           69           59           56           60
# 4            0            1            0            1            2
#
#    y_sample997  y_sample998  y_sample999
# 0            2            1            2
# 1            0            0            0
# 2           21           25           15
# 3           37           43           37
# 4            2            3            0
#
# [5 rows x 1000 columns]

# %%
pred_quantiles.head()
# Out:
#    quant_0.05  quant_0.95
# 0           1           9
# 1           0           0
# 2          14          63
# 3          19          93
# 4           0           3

# %%
pred_params.head()
# Out:
#    total_count     probs      gate
# 0     6.001122  0.414737  0.001764
# 1     6.248660  0.001844  0.001764
# 2     6.001122  0.853568  0.001764
# 3     5.817155  0.897247  0.001764
# 4     6.197020  0.114580  0.001764

# %% [markdown]
# # SHAP Interpretability

# %%
# Partial Dependence Plot of total_count parameter
xgblss.plot(X_test,
            parameter="total_count",
            feature="persons",
            plot_type="Partial_Dependence")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# Feature Importance of probs parameter
xgblss.plot(X_test,
            parameter="probs",
            plot_type="Feature_Importance")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # Density Plots of Actual and Predicted Samples

# %%
pred_df = pd.melt(pred_samples.iloc[:,0:5])
actual_df = pd.DataFrame.from_dict({"variable": "ACTUAL", "value": y_test.reshape(-1,)})
plot_df = pd.concat([pred_df, actual_df])

(
    ggplot(plot_df, 
           aes(x="value",
               color="variable",
               fill="variable")) +  
    geom_density(alpha=0.4) + 
    facet_wrap("variable",
              scales="free_y",
              ncol=2) + 
    theme_bw(base_size=15) + 
    theme(legend_position="none")
)
# Out:
# <Figure Size: (1800 x 900)>
